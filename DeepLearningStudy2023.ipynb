# %%
from google.colab import drive
from os.path import join
ROOT = "/content/drive"
print(ROOT)
drive.mount(ROOT)
# Out:
# /content/drive
# Mounted at /content/drive

# %%
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/content/drive/MyDrive/Colab Notebooks/DeepLearningStudy' 
# replace with your Github username 
GIT_USERNAME = "HyeonminHan" 
# definitely replace with your
GIT_TOKEN = "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"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "DeepLearningStudy" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/Colab Notebooks/DeepLearningStudy
# mkdir: cannot create directory ‘/content/drive/MyDrive/Colab Notebooks/DeepLearningStudy’: File exists
# GIT_PATH:  https://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@github.com/HyeonminHan/DeepLearningStudy.git

# %%
# %cd "{PROJECT_PATH}"   
# !git init
# Out:
# /content/drive/MyDrive/Colab Notebooks/DeepLearningStudy
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/DeepLearningStudy/.git/

# %%
# !git config --global user.email handy389@naver.com
# !git config --global user.name HyeonminHan

# %%
# !git remote set-url origin https://HyeonminHan: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@github.com/HyeonminHan/DeepLearningStudy.git
# !git push origin main
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://HyeonminHan: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@github.com/HyeonminHan/DeepLearningStudy.git/'

# %%
# !git config --global user.name HyeonminHan

# %%
# !git add . 
# !git commit -m "test2" #커밋메세지를 자유롭게 적어줍니다.\
# !git push origin main
# Out:
# [main 2994a46] test2
#  1 file changed, 1 insertion(+), 1 deletion(-)
